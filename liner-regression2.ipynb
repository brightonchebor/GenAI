# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris

# %%
iris = iris[['petal_length','petal_width']]
iris

# %%
x = iris['petal_length']
y = iris['petal_width']

# %%
import matplotlib.pyplot as plp
plp.scatter(x, y)
plp.xlabel('petal length - Independent')
plp.ylabel('petal height - Dependent')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=23)

# %%
import numpy as np
x_train = np.array(x_train).reshape([-1, 1])
x_train

# %%
x_test = np.array(x_test).reshape([-1, 1])
x_test

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# y = mx + c
m = lr.coef_
c = lr.intercept_
m, c
# Out:
# (array([0.41684538]), np.float64(-0.3511327422143746))

# %%
# predict function
y_pred = lr.predict(x_train)
y_pred

# %%
import matplotlib.pyplot as plp
plp.scatter(x_train, y_train)
plp.plot(x_train, y_pred, color='red')
plp.xlabel('petal length - Independent')
plp.ylabel('petal height - Dependent')

# %%
y_pred_train =lr.predict(x_test)
y_pred_train

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred_train, color='red')
plp.xlabel('petal length - Independent')
plp.ylabel('petal height - Dependent')
# Out:
# Text(0, 0.5, 'petal height - Dependent')
